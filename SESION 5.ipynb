# %% [markdown]
# ## Programación Lineal

# %% [markdown]
# Una compañía produce dos productos ($X_1$ y $X_2$) usando dos máquinas ($A$ y $B$). Cada unidad de **$X_1$ que se produce requiere 50 minutos en la máquina $A$** y 30 minutos en la máquina $B$. Cada unidad de **$X_2$ que se produce requiere 24 minutos en la máquina $A$** y 33 minutos en la máquina $B$.
#
# Al comienzo de la semana hay 30 unidades de $X_1$ y 90 unidades de $X_2$ en inventario. El tiempo de uso disponible de la **máquina $A$ es de 40 horas** y el de la máquina $B$ es de 35 horas.
#
# La demanda para $X_1$ en la semana actual es de 75 unidades y de $X_2$ es de 95 unidades. La política de la compañía es maximizar la suma combinada de unidades de $X_1$ e $X_2$ en inventario al finalizar la semana.
#
# Formular el problema de decidir cuánto hacer de cada producto en la semana como un problema de programación lineal.
#
# Sean:
# - $x_1$ la cantidad de unidades de $X_1$ a ser producidas en la semana, y
# - $x_2$ la cantidad de unidades de $X_2$ a ser producidas en la semana.
#
# Notar que lo que se quiere es maximizar $x_1+x_2$.
#
# Restricciones:
# 1. El tiempo de uso disponible de la máquina $A$ es de 40 horas: $50x_1+24x_2\leq 40(60)\Rightarrow 50x_1+24x_2\leq 2400$.
# 2. El tiempo de uso disponible de la máquina $B$ es de 35 horas: $30x_1+33x_2\leq 35(60)\Rightarrow 30x_1+33x_2\leq 2100$.
# 3. La demanda para $X_1$ en la semana actual es de 75 unidades: $x_1+30\geq 75\Rightarrow x_1\geq 45\Rightarrow -x_1\leq -45$.
# 4. La demanda para $X_2$ en la semana actual es de 95 unidades: $x_2+90\geq 95\Rightarrow x_2\geq 5\Rightarrow -x_2\leq -5$.

# %% [markdown]
# ### Solucion Gráfica

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %% [markdown]
# Se tienen las desigualdades:
# $$50x_1+24x_2\leq 2400$$
# $$30x_1+33x_2\leq 2100$$
#
# Para hacer la gráfica se pasan a igualdades y se despeja una variable:
# $$24x_2 + 50x_2 = 2400 $$
# $$33x_2 + 30x_2 = 2100 $$
#
# El despeje queda como:
# 1. $x_2 = \frac{2400 - 50x_1}{24} $
#
# 2. $x_2 = \frac{2100 - 30x_1}{33} $
#
# 3. $x_1\geq 45 $
#
# 4. $x_2\geq 5 $

# %%
#Ecuación 1 (de la máquina A)
def x2_v1(x1):
    return (2400 - 50*x1)/24
#Ecuación 2 (de la máquina B)
def x2_v2(x1):
    return (2100 - 30*x1)/33

# %%
#Inicialmente no se sabe el valor, se pone un estandar como (0, 100)
x1 = np.linspace(0, 100)

# %%
#Desigualdad 1
plt.plot(x1, x2_v1(x1), 'magenta')
#Desigualdad 2
plt.plot(x1, x2_v2(x1));

# %%
plt.plot(x1, x2_v1(x1), 'magenta')
plt.plot(x1, x2_v2(x1))

#Se grafican las eq. 3 & 4
plt.plot([45, 45], [0, 25], 'k')
plt.plot([43, 47], [5, 5], 'r');

# %%
plt.plot(x1, x2_v1(x1), 'magenta')
plt.plot(x1, x2_v2(x1))
plt.plot([45, 45], [0, 25], 'k')
plt.plot([43, 47], [5, 5], 'r')

#Se hace un zoom
plt.xlim(xmin = 25, xmax = 50)
plt.ylim(ymin = -5, ymax = 45);

# %%
plt.plot(x1, x2_v1(x1), 'magenta')
plt.plot(x1, x2_v2(x1))
plt.plot([45, 45], [0, 25], 'k')
plt.plot([43, 47], [5, 5], 'r')
plt.xlim(xmin = 25, xmax = 50)
plt.ylim(ymin = -5, ymax = 45)

#Se indican cuáles son los ejes de la gráfica
plt.xlabel(r"$x_1$", fontsize = 18)
plt.ylabel(r"$x_2$", fontsize = 18)

# Se ponen puntos de las esquinas de cada línea
plt.scatter([45, 45], [0, 25], s=200, color = "red")
plt.scatter([43, 47], [5, 5], s=200, color = "red");

# %% [markdown]
# La solución sólo puede ser de la "cruz" para adelante.
# Las restricciones indican que la zona óptima, los mínimos, es el triángulo pequeño.

# %%
plt.plot(x1, x2_v1(x1), 'magenta')
plt.plot(x1, x2_v2(x1))
plt.plot([45, 45], [0, 25], 'k')
plt.plot([43, 47], [5, 5], 'r')
plt.xlabel(r"$x_1$", fontsize = 18)
plt.ylabel(r"$x_2$", fontsize = 18)

#Se hace un zoom a la zona de optimización
plt.xlim(xmin = 44.5, xmax = 46)
plt.ylim(ymin = 4.5, ymax = 7);

# %%
plt.plot(x1, x2_v1(x1), 'magenta')
plt.plot(x1, x2_v2(x1))
plt.plot([45, 45], [0, 25], 'k')
plt.plot([43, 47], [5, 5], 'r')
plt.xlabel(r"$x_1$", fontsize = 18)
plt.ylabel(r"$x_2$", fontsize = 18)
plt.xlim(xmin = 44.5, xmax = 46)
plt.ylim(ymin = 4.5, ymax = 7)

#Se pone un relleno en el triángulo (no lo vimos a detalle)
plt.fill_between(np.array([45, 45.6]), x2_v1(np.array([45, 45.6])),
                5*np.ones(2), alpha = .2, color = 'orange');

# %% [markdown]
# El punto posible para la solución es: $(45, 5)$. Los otros son $(45.6, 5)$ y $(45, 6.25)$

# %%
plt.plot(x1, x2_v1(x1), 'magenta')
plt.plot(x1, x2_v2(x1))
plt.plot([45, 45], [0, 25], 'k')
plt.plot([43, 47], [5, 5], 'r')
plt.xlabel(r"$x_1$", fontsize = 18)
plt.ylabel(r"$x_2$", fontsize = 18)
plt.xlim(xmin = 44.5, xmax = 46)
plt.ylim(ymin = 4.5, ymax = 7)
plt.fill_between(np.array([45, 45.6]), x2_v1(np.array([45, 45.6])),
                5*np.ones(2), alpha = .2, color = 'orange')
#Intersecciones
plt.scatter([45, 45, 45.6], [5, 6.25, 5], color = "red");

# %% [markdown]
# ### Solución con linprog

# %%
import scipy.optimize as opt

# %% [markdown]
# Usando:
# $$50x_1+24x_2\leq 2400$$
# $$30x_1+33x_2\leq 2100$$

# %%
# Optimizar min(-x1, - x2), se saca el minimo del negativo porque es mejor minimizar que maximizar en programacion
c = np.array([-1, -1])

#Coeficientes de las variables
A = np.array([[50, 24], [30, 33]])
#Resultados de las ecuaciones
b = np.array([2400, 2100])

#Restricción de ecuación 3
x1_bound = (45, None)
#Restricción de ecuación 4
x2_bound = (5, None)

# %%
#Función para solucionar
res = opt.linprog(c, A_ub=A, b_ub=b, bounds=(x1_bound, x2_bound), options={'disp':True})
# Out:
# Optimization terminated successfully.
#          Current function value: -51.250000
#          Iterations: 4

# %%
res
# Out:
#      fun: -51.25
#  message: 'Optimization terminated successfully.'
#      nit: 4
#    slack: array([  0.  , 543.75,   0.  ,   1.25])
#   status: 0
#  success: True
#        x: array([45.  ,  6.25])

# %% [markdown]
# En inventario hay 30 de $x_1$ y 90 de $x_2$. La demanda es de 75 de $x_1$ y 95 de $x_2$.

# %% [markdown]
# Se puede producir 75 de $x_1$ y 96.5 $x_2$, entonces apenas y se cumple.

# %% [markdown]
# #### Actividad.
# Mónica hace aretes y cadenitas de joyería. Es tan buena, que todo lo que hace lo vende.
#
# Le toma 30 minutos hacer un par de aretes y una hora hacer una cadenita, y como Mónica también es estudihambre, solo dispone de 10 horas a la semana para hacer las joyas. Por otra parte, el material que compra solo le alcanza para hacer 15 unidades (el par de aretes cuenta como unidad) de joyas por semana.
#
# La utilidad que le deja la venta de las joyas es $15$ en cada par de aretes y $20$ en cada cadenita.
#
# ¿Cuántos pares de aretes y cuántas cadenitas debería hacer Mónica para maximizar su utilidad?

# %% [markdown]
# #### Solución
# $x_1$ es la cantidad de aretes y $x_2$ es la cantidad de cadenitas. Se quiere maximizar $x_1 + x_2$.

# %% [markdown]
# Cuántas horas consume Mónica haciendo las joyas sin pasar de 10 horas:
# $$0.5x_1 + x_2 \leq 10$$
# Cuántas unidades usa para producir los dos tipos de joyas sin pasar de 15 unidades:
# $$x_1 + x_2 \leq 15$$

# %%
import numpy as np
import scipy.optimize as opt

#Se encuentra el máximo. Se pone el valor de la utilidad de cada tipo de joya.
c = np.array([-15, -20])

#Coeficientes de las variables
A = np.array([[0.5, 1], [1, 1]])
#Resultados de las ecuaciones
b = np.array([10, 15])

#Restricción de las ecuaciones (sólo no pueden ser negativos)
x1_bound = (0, None)
#Restricción de ecuación 4
x2_bound = (0, None)

#Función para solucionar
res = opt.linprog(c, A_ub=A, b_ub=b, bounds=(x1_bound, x2_bound), options={'disp':True})

#Mostrar resultado
res
# Out:
# Optimization terminated successfully.
#          Current function value: -250.000000
#          Iterations: 2
#      fun: -250.0
#  message: 'Optimization terminated successfully.'
#      nit: 2
#    slack: array([0., 0.])
#   status: 0
#  success: True
#        x: array([10.,  5.])

# %% [markdown]
# La producción se maximiza produciendo 10 pares de aretes y 5 cadenitas, y lo máximo que puede ganar es 250 pesos a la semana.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

#Ecuación 1 (horas de trabajo)
def x2_v1(x1):
    return 10 - 0.5 * x1
#Ecuación 2 (cantidad de material)
def x2_v2(x1):
    return 15 - x1

x1 = np.linspace(0, 100)
plt.plot(x1, x2_v1(x1), 'magenta')
plt.plot(x1, x2_v2(x1), 'blue')

plt.xlabel(r"$x_1$", fontsize = 18)
plt.ylabel(r"$x_2$", fontsize = 18)

plt.plot([45, 45], [0, 25], 'k')
plt.plot([43, 47], [5, 5], 'r')
